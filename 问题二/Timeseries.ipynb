# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('./误差带5.xlsx')
df.shape
# Out:
# (3000, 3)

# %%
df.rename(columns={'x':'days', 'y': 'IC depth'},inplace=True)
df.head()
# Out:
#    days  IC depth   line
# 0     1     0.704  line1
# 1     2     0.712  line1
# 2     3     0.746  line1
# 3     4     0.764  line1
# 4     5     0.734  line1

# %%
plt.figure(dpi=100, figsize=(12, 8))
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
# fmri = sns.load_dataset("fmri")


# Plot the responses for different events and regions
g = sns.lineplot(x="days", y='IC depth',hue='line', data=df)
g.set_xticks(range(1, 21, 2))
# Out:
# [<matplotlib.axis.XTick at 0x1a59fd5b4f0>,
#  <matplotlib.axis.XTick at 0x1a59fd5beb0>,
#  <matplotlib.axis.XTick at 0x1a5a00e0550>,
#  <matplotlib.axis.XTick at 0x1a59ffe9940>,
#  <matplotlib.axis.XTick at 0x1a59fe4d6a0>,
#  <matplotlib.axis.XTick at 0x1a59ffe9e80>,
#  <matplotlib.axis.XTick at 0x1a59fe4d370>,
#  <matplotlib.axis.XTick at 0x1a59fffe100>,
#  <matplotlib.axis.XTick at 0x1a59fffe850>,
#  <matplotlib.axis.XTick at 0x1a59ffa20a0>]

# %%
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
